# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo

import yfinance as yf

# %%
result= yf.Ticker("AAPL")
#print(result.history(period="max"))
Apple = pd.DataFrame(result.history(period="5y"))
#data2.head()
result2 = yf.Ticker("PFE")
#print(result.history(period="max"))
Pfizer = pd.DataFrame(result2.history(period="max"))

result3 = yf.Ticker("AAL")
AAL = pd.DataFrame(result3.history(period="5y"))

result4 = yf.Ticker("T") 
ATT = pd.DataFrame(result4.history(period="max"))



Apple
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-11-18 00:00:00-05:00   64.422104   64.817169   64.041588   64.737190
# 2019-11-19 00:00:00-05:00   64.931076   64.955315   64.322731   64.540863
# 2019-11-20 00:00:00-05:00   64.359097   64.489971   63.113308   63.789524
# 2019-11-21 00:00:00-05:00   63.910706   63.988266   63.302353   63.503525
# 2019-11-22 00:00:00-05:00   63.644104   63.787102   63.219955   63.447784
# ...                               ...         ...         ...         ...
# 2024-11-11 00:00:00-05:00  225.000000  225.699997  221.500000  224.229996
# 2024-11-12 00:00:00-05:00  224.550003  225.589996  223.360001  224.229996
# 2024-11-13 00:00:00-05:00  224.009995  226.649994  222.759995  225.119995
# 2024-11-14 00:00:00-05:00  225.020004  228.869995  225.000000  228.220001
# 2024-11-15 00:00:00-05:00  226.399994  226.919998  224.270004  225.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# Let's see a historical view of the closing price
plt.figure(figsize=(15, 10))
plt.subplot(2,2,1)
plt.plot(Apple.index, Apple['Close'], linewidth=2)
plt.ylabel('Closing Price($)')
plt.xlabel('Year')
plt.title(f"Closing Price of Apple")

plt.subplot(2,2,2)
plt.plot(AAL.index, AAL['Close'], linewidth=2)
plt.ylabel("Closing Price($)")
plt.xlabel('Year')
plt.title("Closing Price of AA")


plt.savefig('why.png')
plt.tight_layout()

# %%
# try to find seasonal trend (not used)
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
# Multiplicative Decomposition 
multiplicative_decomposition = seasonal_decompose(Apple['Close'], model='multiplicative', period=100)

plt.rcParams.update({'figure.figsize': (16,12)})
fig = multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()
